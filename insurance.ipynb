# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Gathering and Assessing Data:

# %%
df = pd.read_csv(r'C:\Users\Function\Desktop\AI\insurance\insurance-data.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Bmi: weight/(height)^2 , It is used to broadly classify a person as underweight, normal weight, overweight or obese based on tissue mass (muscle, fat, and bone) and height.
#
# Charges: pay for insurance

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df[["sex", "smoker", "region"]].describe()
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %%
df["sex"].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df["region"].value_counts()
# Out:
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df["charges"].value_counts()
# Out:
# 1639.56310     2
# 11987.16820    1
# 7624.63000     1
# 12523.60480    1
# 10355.64100    1
#               ..
# 62592.87309    1
# 18903.49141    1
# 8538.28845     1
# 11165.41765    1
# 60021.39897    1
# Name: charges, Length: 1337, dtype: int64

# %%
df["bmi"].value_counts()
# Out:
# 32.300    13
# 28.310     9
# 30.800     8
# 34.100     8
# 28.880     8
#           ..
# 44.745     1
# 26.070     1
# 27.300     1
# 37.715     1
# 29.200     1
# Name: bmi, Length: 548, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df["children"].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %% [markdown]
# #

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Data visualization :

# %% [markdown]
# ### Univarient analysis :-

# %%
plt.figure(figsize=[15,10])

plt.subplot(2,2,1)
sns.countplot(x=df['sex'])

plt.subplot(2,2,2)
sns.countplot(x=df['children'])

plt.subplot(2,2,3)
sns.countplot(x=df['region'])

plt.subplot(2,2,4)
sns.countplot(x=df['smoker']);

# %% [markdown]
# - The number of male is slightly more than that of female.
# - Very few people have more than three children.
# - Regions are very close in number, but southwest is the most numerous in number, but very little more.
# - Very few smokers.

# %%
plt.figure(figsize=[15,10])
sns.countplot(x='age', data = df);

# %% [markdown]
# - Most people are 18 years old, then 19 years old

# %%
plt.figure(figsize=[25,18])

plt.subplot(2,2,1)
plt.pie(df["sex"].value_counts() ,labels=["male", "female"], autopct='%1.1f%%', textprops={'fontsize': 18})
plt.title("Percentage of males and females",fontsize=15)
plt.legend()

plt.subplot(2,2,2)
plt.pie(df["children"].value_counts() ,labels=["0", "1", "2", "3", "4", "5"], autopct='%1.1f%%', textprops={'fontsize': 18}, explode = (0.08, 0, 0, 0.08, 0.2, 0))
plt.title("Percentage of number of children",fontsize=15)
plt.legend()

plt.subplot(2,2,3)
plt.pie(df["region"].value_counts() ,labels=["southeast", "southwest", "northwest", "northeast"], autopct='%1.1f%%', textprops={'fontsize': 18})
plt.title("Percentage of regions",fontsize=15)
plt.legend()

plt.subplot(2,2,4)
plt.pie(df["smoker"].value_counts() ,labels=["no", "yes"], autopct='%1.1f%%', textprops={'fontsize': 18})
plt.title("Percentage of skmker and non smoker",fontsize=15)
plt.legend()

# %%
plt.figure(figsize=[15,10])

plt.subplot(2,2,1)
sns.boxplot(x=df['age'])

plt.subplot(2,2,2)
sns.boxplot(x=df['children'])

plt.subplot(2,2,3)
sns.boxplot(x=df['bmi'])

plt.subplot(2,2,4)
sns.boxplot(x=df['charges']);

# %% [markdown]
# - There are outliers in bmi and charges.

# %%
plt.figure(figsize=[15,10])

plt.subplot(2,3,1)
sns.histplot(x=df['sex'])

plt.subplot(2,3,2)
sns.histplot(x=df['children'])

plt.subplot(2,3,3)
sns.histplot(x=df['region'])

plt.subplot(2,3,4)
sns.histplot(x=df['smoker'])

plt.subplot(2,3,5)
sns.histplot(x=df['age'])

plt.subplot(2,3,6)
sns.histplot(x=df['bmi']);

# %% [markdown]
# - A lot of people are 30 kg/m^2 in BMI.

# %% [markdown]
# ### Multivariant analysis :-

# %%
sns.countplot(x = "sex", data = df , hue = "smoker")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# The most smokers are from men

# %%
sns.countplot(x = "region", data = df , hue = "smoker")
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %% [markdown]
# The most smokers are from southeast

# %%
sns.set(rc={"figure.figsize":(20, 5)})
sns.countplot(x = "age", data = df , hue = "smoker")
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %% [markdown]
# The most smokers are 19 years old

# %%
plt.figure(figsize=[15,10])

plt.subplot(2,3,1)
sns.scatterplot(x = "age" , y='charges', data = df )

plt.subplot(2,3,2)
sns.scatterplot(x = "sex" , y='charges', data = df )

plt.subplot(2,3,3)
sns.scatterplot(x = "children" , y='charges', data = df )

plt.subplot(2,3,4)
sns.scatterplot(x = "region" , y='charges', data = df )

plt.subplot(2,3,5)
sns.scatterplot(x = "bmi" , y='charges', data = df )

plt.subplot(2,3,6)
sns.scatterplot(x = "smoker" , y='charges', data = df )
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %% [markdown]
# - over 50000 in charges are outliers.

# %%
plt.figure(figsize=[20,10])

plt.subplot(2,3,1)
sns.scatterplot(x = "age" , y='charges', hue = "sex" , data = df )

plt.subplot(2,3,2)
sns.scatterplot(x = "age" , y='charges', hue = "children" , data = df )

plt.subplot(2,3,3)
sns.scatterplot(x = "age" , y='charges', hue = "region" , data = df )

plt.subplot(2,3,4)
sns.scatterplot(x = "age" , y='charges', hue = "bmi" , data = df )

plt.subplot(2,3,5)
sns.scatterplot(x = "age" , y='charges', hue = "smoker" , data = df )
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %% [markdown]
# - 1st fig: males pay more than females and ages in both pay more than youth.
# - 2nd fig: charges increase when the number if children increased.
# - 3rd fig: the people who live in southeast pay more than other and ages that live in pay more.
# - 4th fig: charges increase when the number if BMI increased and ages in all pay more than youth.
# - 5th fig: smoker people pays charges more than non smoker people and ages in both pay more than youth.

# %%
plt.figure(figsize=[15,10])

plt.subplot(2,2,1)
sns.violinplot(x = "sex" , y='charges', data = df )

plt.subplot(2,2,2)
sns.violinplot(x = "children" , y='charges', data = df )

plt.subplot(2,2,3)
sns.violinplot(x = "region" , y='charges', data = df )

plt.subplot(2,2,4)
sns.violinplot(x = "smoker" , y='charges', data = df )
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
plt.figure(figsize=[20,5])

plt.subplot(1,3,1)
sns.violinplot(x = "sex" , y='charges', hue='smoker', data = df )

plt.subplot(1,3,2)
sns.violinplot(x = "children" , y='charges', hue='smoker', data = df )

plt.subplot(1,3,3)
sns.violinplot(x = "region" , y='charges', hue='smoker', data = df )
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %%
plt.figure(figsize=[6,5])
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# age and charges has a strong relation

# %% [markdown]
# # Clean and fix data:

# %% [markdown]
# ### we should remove the duplicated row

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# we remove it successfully

# %% [markdown]
# ### we should remove outliers

# %% [markdown]
# #### Charges outliers

# %%
charges_outliers = df[ df['charges'] >= 50000 ].count() 
charges_outliers
# Out:
# age         7
# sex         7
# bmi         7
# children    7
# smoker      7
# region      7
# charges     7
# dtype: int64

# %% [markdown]
# 7 for 1338 is not a large number, it will not affect when droped

# %%
charges_outliers = df[df['charges'] >= 50000 ].index
df.drop(charges_outliers , inplace=True)
# Out:
# C:\Users\Function\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
sns.boxplot(x=df['charges']);

# %% [markdown]
# The ourliers that exist btween 32500 and 50000 it is natural to exist, which does not require their removal.

# %% [markdown]
# #### BMI outliers

# %%
bmi_outliers = df[df['bmi'] >= 46 ].index
df.drop(bmi_outliers , inplace=True)
# Out:
# C:\Users\Function\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
sns.boxplot(x=df['bmi']);

# %% [markdown]
# we remove it successfully

# %% [markdown]
# #  Prepare data to ML :

# %% [markdown]
# ### We should convert non numerical data to numerical data

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %% [markdown]
# we convert it successfully

# %%
plt.figure(figsize=[12,10])
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# smoker and charges has a very strong relation

# %% [markdown]
# #
